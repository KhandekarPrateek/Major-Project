# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# 1) Read the CSV files
df1 = pd.read_csv("tree_species.csv")
df2 = pd.read_csv("merged_df1_df2.csv")

# 2) Extract the relevant columns into separate DataFrames
df1_names = df1[['Botanical Name']].copy()
df2_names = df2[['plant_name']].copy()

# 3) Load the SentenceTransformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

# 4) Create embeddings for each botanical name in both DataFrames
df1_names['embedding'] = df1_names['Botanical Name'].apply(lambda x: model.encode(str(x)))
df2_names['embedding'] = df2_names['plant_name'].apply(lambda x: model.encode(str(x)))

# 5) Set a cosine similarity threshold for matching
threshold = 0.80

# 6) Find plants in df1 that do NOT have any similar match in df2 above the threshold
unmatched_plants = []

for i, row1 in df1_names.iterrows():
    emb1 = row1['embedding'].reshape(1, -1)
    match_found = False

    # Check against each plant in df2
    for j, row2 in df2_names.iterrows():
        emb2 = row2['embedding'].reshape(1, -1)
        sim = cosine_similarity(emb1, emb2)[0][0]
        if sim >= threshold:
            match_found = True
            break  # No need to check further if a match is found

    # If no match was found, add the plant to the unmatched list
    if not match_found:
        unmatched_plants.append(row1['Botanical Name'])

# 7) Print the list of unmatched plants
print("Plants in tree_species.csv not present in merged_df1_df2.csv (based on vector similarity):")
for plant in unmatched_plants:
    print(plant)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Plants in tree_species.csv not present in merged_df1_df2.csv (based on vector similarity):
# Terminalia Chebula
# Terminalia Arjuna
# Terminalia Tomentosa
# Hardwickia Binata
# Dalbergia Sissoo
# Albizia Procera
# Putranjiva Roxburghii Wall
# Spathodea Campanulata
# Anogeissus Latifolia
# Oroxylum Indicum
# Senegalia Catechu
# Putranjiva Roxburghii Wall
# Saraca Asoca
# Jacaranda Mimosifolia
# Dalbergia Gardenia
# Cestrum Nocturnum
# Handroanthus Impetiginosus
# Rauvolfia Serpentina

# %%
df2.head()
# Out:
#                         plant_name  \
# 0        Aegle marmelos (L.) Corr.
# 1      Alpinia galanga (L.) Willd.
# 2            Amaranthus viridis L.
# 3    Artocarpus heterophyllus Lam.
# 4  Azadirachta indica (L.) A.Juss.
#
#                                            embedding              source
# 0  [-4.91057150e-02  6.15545809e-02 -2.40750611e-...  df2 (intersection)
# 1  [-2.07084678e-02  6.79903664e-03 -6.37864247e-...  df2 (intersection)
# 2  [-1.44480709e-02  4.78543751e-02 -7.27312267e-...  df2 (intersection)
# 3  [ 1.08356848e-02  9.64791998e-02 -7.25910738e-...  df2 (intersection)
# 4  [-3.44188362e-02  1.09954931e-01 -9.46124271e-...  df2 (intersection)

# %%
import pandas as pd

# Suppose df2 already exists in memory with columns: ['plant_name', 'embedding', 'source']

# 1) Drop unwanted columns
df2_final = df2.drop(['embedding', 'source'], axis=1)

# 2) List of new plant names to add
new_plants = [
    "Terminalia Chebula",
    "Terminalia Arjuna",
    "Terminalia Tomentosa",
    "Hardwickia Binata",
    "Dalbergia Sissoo",
    "Albizia Procera",
    "Putranjiva Roxburghii Wall",
    "Spathodea Campanulata",
    "Anogeissus Latifolia",
    "Oroxylum Indicum",
    "Senegalia Catechu",
    "Putranjiva Roxburghii Wall",
    "Saraca Asoca",
    "Jacaranda Mimosifolia",
    "Dalbergia Gardenia",
    "Cestrum Nocturnum",
    "Handroanthus Impetiginosus",
    "Rauvolfia Serpentina"
]

# 3) Create a new DataFrame with these additional names
df_new_plants = pd.DataFrame(new_plants, columns=["plant_name"])

# 4) Concatenate with the df2_final
df2_final = pd.concat([df2_final, df_new_plants], ignore_index=True)

# 5) Export to CSV
df2_final.to_csv("finalCSV_Major_Project.csv", index=False)

print("finalCSV_Major_Project.csv created successfully!")
# Out:
# finalCSV_Major_Project.csv created successfully!

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# 1) Read the CSV file
df = pd.read_csv("finalCSV_Major_Project.csv")

# 2) Load the SentenceTransformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

# 3) Create embeddings for each plant_name
df['embedding'] = df['plant_name'].apply(lambda x: model.encode(str(x)))

# 4) Compare all pairs using cosine similarity
duplicates = []
threshold = 0.80  # Adjust as needed

for i in range(len(df) - 1):
    emb_i = df.loc[i, 'embedding'].reshape(1, -1)
    for j in range(i + 1, len(df)):
        emb_j = df.loc[j, 'embedding'].reshape(1, -1)
        sim = cosine_similarity(emb_i, emb_j)[0][0]
        if sim >= threshold:
            duplicates.append({
                "name1": df.loc[i, 'plant_name'],
                "name2": df.loc[j, 'plant_name'],
                "similarity": sim
            })

# 5) Check and print results
if len(duplicates) > 0:
    print("Potential duplicates found (similarity >= {}):".format(threshold))
    for d in duplicates:
        print(d)
else:
    print(0)
# Out:
# Potential duplicates found (similarity >= 0.8):
# {'name1': 'Amaranthus viridis L.', 'name2': 'Amaranthus lividus L.', 'similarity': 0.8192979}
# {'name1': 'Amaranthus viridis L.', 'name2': 'Amaranthus caudatus L.', 'similarity': 0.8715073}
# {'name1': 'Amaranthus viridis L.', 'name2': 'Amaranthus spinosus L.', 'similarity': 0.8272556}
# {'name1': 'Crotalaria juncea L.', 'name2': 'Crotalaria retusa L.', 'similarity': 0.8603959}
# {'name1': 'Hibiscus rosa-sinensis L.', 'name2': 'Hibiscus surattensis L.', 'similarity': 0.8669882}
# {'name1': 'Abelmoschus manihot (L.) Medik.', 'name2': 'Abelmoschus moschatus Medik.', 'similarity': 0.82750934}
# {'name1': 'Acacia catechu (L.f.) Willd.', 'name2': 'Acacia farnesiana (L.) Willd.', 'similarity': 0.82852256}
# {'name1': 'Acacia catechu (L.f.) Willd.', 'name2': 'Acacia leucophloea (Roxb.) Willd.', 'similarity': 0.8015326}
# {'name1': 'Acacia catechu (L.f.) Willd.', 'name2': 'Acacia pennata (L.) Willd.', 'similarity': 0.85371786}
# {'name1': 'Acacia catechu (L.f.) Willd.', 'name2': 'Acacia senegal (L.) Willd.', 'similarity': 0.8794005}
# {'name1': 'Acacia farnesiana (L.) Willd.', 'name2': 'Acacia leucophloea (Roxb.) Willd.', 'similarity': 0.81300724}
# {'name1': 'Acacia farnesiana (L.) Willd.', 'name2': 'Acacia pennata (L.) Willd.', 'similarity': 0.85340655}
# {'name1': 'Acacia farnesiana (L.) Willd.', 'name2': 'Acacia senegal (L.) Willd.', 'similarity': 0.84590703}
# {'name1': 'Acacia leucophloea (Roxb.) Willd.', 'name2': 'Acacia senegal (L.) Willd.', 'similarity': 0.8176967}
# {'name1': 'Acacia pennata (L.) Willd.', 'name2': 'Acacia senegal (L.) Willd.', 'similarity': 0.82757044}
# {'name1': 'Aconitum laciniatum (Bruhl) Stapf', 'name2': 'Aconitum spicatum (Bruhl) Stapf', 'similarity': 0.85468185}
# {'name1': 'Adiantum caudatum L.', 'name2': 'Adiantum venustum D.Don', 'similarity': 0.8257017}
# {'name1': 'Agave americana Blanco', 'name2': 'Agave americana L.', 'similarity': 0.8359641}
# {'name1': 'Alhagi pseudoalhagi (Bieb.) Desv.', 'name2': 'Alhagi pseudoalhagi (Bieb.) Desv.', 'similarity': 1.0000001}
# {'name1': 'Amaranthus lividus L.', 'name2': 'Amaranthus tricolor L.', 'similarity': 0.8032255}
# {'name1': 'Amaranthus lividus L.', 'name2': 'Amaranthus caudatus L.', 'similarity': 0.8775489}
# {'name1': 'Amaranthus lividus L.', 'name2': 'Amaranthus spinosus L.', 'similarity': 0.87372386}
# {'name1': 'Amaranthus tricolor L.', 'name2': 'Amaranthus caudatus L.', 'similarity': 0.83214027}
# {'name1': 'Amaranthus tricolor L.', 'name2': 'Amaranthus spinosus L.', 'similarity': 0.8026716}
# {'name1': 'Amaranthus caudatus L.', 'name2': 'Amaranthus spinosus L.', 'similarity': 0.86879075}
# {'name1': 'Anthemis cotula L.', 'name2': 'Cotula anthemoides L.', 'similarity': 0.89081347}
# {'name1': 'Artemisia absynthium L.', 'name2': 'Artemisia dracunculcus L.', 'similarity': 0.8161117}
# {'name1': 'Artemisia absynthium L.', 'name2': 'Artemisia maritima L.', 'similarity': 0.83887565}
# {'name1': 'Artemisia absynthium L.', 'name2': 'Artemisia persica Boiss.', 'similarity': 0.82018125}
# {'name1': 'Artemisia dracunculcus L.', 'name2': 'Artemisia maritima L.', 'similarity': 0.8269876}
# {'name1': 'Artemisia indica Willd.', 'name2': 'Artemisia sivarsiana Ehrh. Ex. Willd.', 'similarity': 0.8430815}
# {'name1': 'Artemisia maritima L.', 'name2': 'Artemisia persica Boiss.', 'similarity': 0.814578}
# {'name1': 'Artemisia maritima L.', 'name2': 'Artemisia sivarsiana Ehrh. Ex. Willd.', 'similarity': 0.8064145}
# {'name1': 'Artemisia persica Boiss.', 'name2': 'Artemisia sacrorum Ledeb.', 'similarity': 0.81091}
# {'name1': 'Avena sativa L.', 'name2': 'Vicia sativa L.', 'similarity': 0.81375325}
# {'name1': 'Barleria longiflora L.f.', 'name2': 'Barleria noctiflora L.f.', 'similarity': 0.8595649}
# {'name1': 'Breynia retusa (Dennst.) Alston', 'name2': 'Breynia retusa (L.) Spreng.', 'similarity': 0.8119873}
# {'name1': 'Caesalpinia crista L.', 'name2': 'Caesalpinia sappan L.', 'similarity': 0.81645864}
# {'name1': 'Calophyllum apetalum Willd.', 'name2': 'Calophyllum inophyllum L.', 'similarity': 0.8349565}
# {'name1': 'Calophyllum inophyllum L.', 'name2': 'Ceratophyllum demursum L.', 'similarity': 0.84769374}
# {'name1': 'Capsicum annum L.', 'name2': 'Capsicum frutescens L.', 'similarity': 0.81354785}
# {'name1': 'Cassia pumila Lam.', 'name2': 'Cassia siamea Lam.', 'similarity': 0.83710045}
# {'name1': 'Cassia absus L.', 'name2': 'Cassia alata L.', 'similarity': 0.85416466}
# {'name1': 'Cassia absus L.', 'name2': 'Cassia alata L.', 'similarity': 0.85416466}
# {'name1': 'Cassia absus L.', 'name2': 'Cassia tora L.', 'similarity': 0.80822945}
# {'name1': 'Cassia alata L.', 'name2': 'Cassia alata L.', 'similarity': 1.0}
# {'name1': 'Cassia alata L.', 'name2': 'Cassia tora L.', 'similarity': 0.8463768}
# {'name1': 'Cassia alata L.', 'name2': 'Cassia tora L.', 'similarity': 0.8463768}
# {'name1': 'Cassia auriculata L.', 'name2': 'Cassia obtusifolia L.', 'similarity': 0.8588364}
# {'name1': 'Cassia sophera L.', 'name2': 'Cassia tora L.', 'similarity': 0.80216956}
# {'name1': 'Chrysanthemum coronarium L.', 'name2': 'Chrysanthemum indicum L.', 'similarity': 0.82055414}
# {'name1': 'Citrus aurantifolia (Christm.) Swingle', 'name2': 'Citrus aurantium L.', 'similarity': 0.81325126}
# {'name1': 'Citrus grandis (L.) Osbeck.', 'name2': 'Citrus sinensis (L.) Osbeck.', 'similarity': 0.8513507}
# {'name1': 'Clinopodium vulgare L.', 'name2': 'Lycopodium clavatum L.', 'similarity': 0.80757505}
# {'name1': 'Clinopodium vulgare L.', 'name2': 'Polypodium vulgare L.', 'similarity': 0.8303616}
# {'name1': 'Corchorus capsularis L.', 'name2': 'Corchorus fascicularis L.', 'similarity': 0.80582064}
# {'name1': 'Cordia myxa Roxb.', 'name2': 'Cordia myxa Roxb. (non L.)', 'similarity': 0.9336777}
# {'name1': 'Crotalaria retusa L.', 'name2': 'Crotalaria sericea Retz.', 'similarity': 0.8086574}
# {'name1': 'Cucumis melo L.', 'name2': 'Cucumis sativus L.', 'similarity': 0.83763766}
# {'name1': 'Cydonia oblonga Mill.', 'name2': 'Opuntia coccinellifera Mill.', 'similarity': 0.8067241}
# {'name1': 'Dalbergia spinosa Roxb.', 'name2': 'Dalbergia stipulacea Roxb.', 'similarity': 0.81582624}
# {'name1': 'Dalbergia spinosa Roxb.', 'name2': 'Dalbergia volubilis Roxb.', 'similarity': 0.82194996}
# {'name1': 'Dalbergia stipulacea Roxb.', 'name2': 'Dalbergia volubilis Roxb.', 'similarity': 0.83161473}
# {'name1': 'Desmodium triflorum (L.) DC.', 'name2': 'Desmodium triquetrum (L.) DC.', 'similarity': 0.83745635}
# {'name1': 'Desmos chinensis Lour.', 'name2': 'Desmos cochinchinensis Lour.', 'similarity': 0.8075131}
# {'name1': 'Diospyros exsculpta Buch.-Ham.', 'name2': 'Diospyros toposia Buch.-Ham.', 'similarity': 0.80585265}
# {'name1': 'Elaeagnus angustifolia L.', 'name2': 'Elaeagnus latifolia L.', 'similarity': 0.9372145}
# {'name1': 'Erythrina stricta Roxb.', 'name2': 'Erythrina suberosa Roxb.', 'similarity': 0.8316121}
# {'name1': 'Euphorbia nivulea Buch.-Ham.', 'name2': 'Euphorbia nivulea Buch.-Ham.', 'similarity': 1.0}
# {'name1': 'Euphorbia pilosa L.', 'name2': 'Euphorbia tirucalli L.', 'similarity': 0.82229686}
# {'name1': 'Euphorbia pilosa L.', 'name2': 'Euphorbia hirta L.', 'similarity': 0.8314182}
# {'name1': 'Euphorbia royleana Boiss.', 'name2': 'Euphorbia thomsoniana Boiss.', 'similarity': 0.85585856}
# {'name1': 'Euphorbia thymifolia L.', 'name2': 'Euphorbia hypericifolia L.', 'similarity': 0.8421758}
# {'name1': 'Euphorbia tirucalli L.', 'name2': 'Euphorbia hirta L.', 'similarity': 0.8053716}
# {'name1': 'Garcinia cambogia (Gaertn.) Desr.', 'name2': 'Garcinia mangostana L.', 'similarity': 0.81229496}
# {'name1': 'Garcinia cambogia (Gaertn.) Desr.', 'name2': 'Garcinia morella (Gaertn.) Desr.', 'similarity': 0.9098609}
# {'name1': 'Garcinia cambogia (Gaertn.) Desr.', 'name2': 'Garcinia pedunculata Roxb.', 'similarity': 0.8135518}
# {'name1': 'Garcinia cowa Roxb.', 'name2': 'Garcinia pedunculata Roxb.', 'similarity': 0.86790717}
# {'name1': 'Garcinia mangostana L.', 'name2': 'Garcinia morella (Gaertn.) Desr.', 'similarity': 0.8067055}
# {'name1': 'Geranium lucidum L.', 'name2': 'Geranium molle L.', 'similarity': 0.8093816}
# {'name1': 'Geranium lucidum L.', 'name2': 'Geranium pusillum Burm.f.', 'similarity': 0.8207773}
# {'name1': 'Geranium lucidum L.', 'name2': 'Geranium robertianum L.', 'similarity': 0.8434081}
# {'name1': 'Geranium lucidum L.', 'name2': 'Geranium rotundifolium L.', 'similarity': 0.84735596}
# {'name1': 'Geranium molle L.', 'name2': 'Geranium robertianum L.', 'similarity': 0.8113111}
# {'name1': 'Geranium nepalense L.', 'name2': 'Geranium nepalense Sweet', 'similarity': 0.8306413}
# {'name1': 'Geranium pusillum Burm.f.', 'name2': 'Geranium rotundifolium L.', 'similarity': 0.821778}
# {'name1': 'Geranium robertianum L.', 'name2': 'Geranium rotundifolium L.', 'similarity': 0.8369499}
# {'name1': 'Haplanthus tentaculatus Nees', 'name2': 'Haplanthus vericillatus Nees', 'similarity': 0.83422863}
# {'name1': 'Hedyotis umbellata (L.) Lam.', 'name2': 'Hedyotis verticillata (L.) Lam.', 'similarity': 0.83970153}
# {'name1': 'Helianthus annuus L.', 'name2': 'Helianthus tuberosus L.', 'similarity': 0.8301013}
# {'name1': 'Heliotropium bacciferum Forsk.', 'name2': 'Heliotropium ovalifolium Forsk.', 'similarity': 0.9053933}
# {'name1': 'Heliotropium curassavicum L.', 'name2': 'Heliotropium indicum L.', 'similarity': 0.82548785}
# {'name1': 'Heliotropium ellipticum Ledeb.', 'name2': 'Heliotropium ovalifolium Forsk.', 'similarity': 0.8213469}
# {'name1': 'Herniaria glabra L.', 'name2': 'Herniaria hirsuta L.', 'similarity': 0.8323499}
# {'name1': 'Hibiscus mutabilis L.', 'name2': 'Hibiscus surattensis L.', 'similarity': 0.8281007}
# {'name1': 'Hibiscus surattensis L.', 'name2': 'Hibiscus syriacus L.', 'similarity': 0.8012435}
# {'name1': 'Indigofera aspalathoides Vahl ex DC.', 'name2': 'Indigofera astragalina DC.', 'similarity': 0.82334507}
# {'name1': 'Indigofera glabra L.', 'name2': 'Indigofera tinctoria L.', 'similarity': 0.80714315}
# {'name1': 'Indigofera glabra L.', 'name2': 'Indigofera trita L.f.', 'similarity': 0.82506955}
# {'name1': 'Indigofera tinctoria L.', 'name2': 'Indigofera trita L.f.', 'similarity': 0.8030325}
# {'name1': 'Indigofera trifoliata L.', 'name2': 'Indigofera trita L.f.', 'similarity': 0.83085203}
# {'name1': 'Ipomoea nil (L.) Roth.', 'name2': 'Ipomoea pes-caprae (L.) Roth', 'similarity': 0.80477893}
# {'name1': 'Ipomoea nil (L.) Roth.', 'name2': 'Ipomoea purpurea (L.) Roth.', 'similarity': 0.84163934}
# {'name1': 'Jasminum azoricum L.', 'name2': 'Jasminum grandiflorum L.', 'similarity': 0.8648204}
# {'name1': 'Jasminum azoricum L.', 'name2': 'Jasminum officinale L.', 'similarity': 0.8011681}
# {'name1': 'Jasminum azoricum L.', 'name2': 'Jasminum scandens Vahl', 'similarity': 0.8095288}
# {'name1': 'Jasminum officinale L.', 'name2': 'Jasminum scandens Vahl', 'similarity': 0.80782723}
# {'name1': 'Lactuca indica L.', 'name2': 'Lactuca sativa L.', 'similarity': 0.85344434}
# {'name1': 'Lactuca indica L.', 'name2': 'Saraca indica L.', 'similarity': 0.80222464}
# {'name1': 'Lactuca remotiflora DC.', 'name2': 'Lactuca runcinata DC.', 'similarity': 0.80983335}
# {'name1': 'Lepidium latifolium L.', 'name2': 'Lepidium sativum L.', 'similarity': 0.81749225}
# {'name1': 'Lupinus albus L.', 'name2': 'Lupinus luteus L.', 'similarity': 0.8776839}
# {'name1': 'Lupinus angustifolius L.', 'name2': 'Lupinus luteus L.', 'similarity': 0.81867266}
# {'name1': 'Malus pumila Mill.', 'name2': 'Malus sylvestris Mill.', 'similarity': 0.81973386}
# {'name1': 'Merremia tridentata (L.) Hallier f.', 'name2': 'Merremia umbellata (L.) Hallier f.', 'similarity': 0.8137347}
# {'name1': 'Mitragyna parvifolia (Roxb.) Korth.', 'name2': 'Mitragyna rotundifolia (Roxb.) Kuntze', 'similarity': 0.8055427}
# {'name1': 'Mormordica balsamina L.', 'name2': 'Mormordica charantia L.', 'similarity': 0.801601}
# {'name1': 'Phyllanthus fraternus Webster', 'name2': 'Phyllanthus maderaspatensis L.', 'similarity': 0.80588305}
# {'name1': 'Piper sylvaticum Roxb.', 'name2': 'Piper trioicum Roxb.', 'similarity': 0.8358096}
# {'name1': 'Pithecellobium angulatum Benth.', 'name2': 'Pithecellobium clypearia Benth.', 'similarity': 0.82997924}
# {'name1': 'Plumeria rubra L.', 'name2': 'Plumeria rubra L. forma acuminata', 'similarity': 0.843704}
# {'name1': 'Polygonum aviculare L.', 'name2': 'Polygonum orientale L.', 'similarity': 0.8147179}
# {'name1': 'Polygonum aviculare L.', 'name2': 'Polygonum plebeium R.Br.', 'similarity': 0.80504894}
# {'name1': 'Polygonum aviculare L.', 'name2': 'Polygonum viviparum L.', 'similarity': 0.84570336}
# {'name1': 'Portulaca oleracea L.', 'name2': 'Portulaca pilosa L.', 'similarity': 0.8601748}
# {'name1': 'Prunus cerasoides D.Don', 'name2': 'Prunus cerasus L.', 'similarity': 0.8022461}
# {'name1': 'Ranunculus muricatus L.', 'name2': 'Ranunculus sceleratus L.', 'similarity': 0.83548784}
# {'name1': 'Rhododendron anthopogon D.Don', 'name2': 'Rhododendron campanulatum D.Don', 'similarity': 0.86874485}
# {'name1': 'Rhododendron anthopogon D.Don', 'name2': 'Rhododendron setosum D.Don', 'similarity': 0.8669512}
# {'name1': 'Rhododendron campanulatum D.Don', 'name2': 'Rhododendron setosum D.Don', 'similarity': 0.87377596}
# {'name1': 'Rumex acetosa L.', 'name2': 'Rumex acetosella L.', 'similarity': 0.90166295}
# {'name1': 'Saussurea lappa (Decne.) Sch.Bip.', 'name2': 'Saussurea obvallata (DC.) Sch.Bip.', 'similarity': 0.8090204}
# {'name1': 'Scirpus grossus L.f.', 'name2': 'Scirpus lacustris L.', 'similarity': 0.80727935}
# {'name1': 'Sida cordifolia L.', 'name2': 'Sida rhombifolia L.', 'similarity': 0.8192415}
# {'name1': 'Sisymbrium altissimum L.', 'name2': 'Sisymbrium irio L.', 'similarity': 0.80119115}
# {'name1': 'Sisymbrium irio L.', 'name2': 'Sisymbrium loeselii L.', 'similarity': 0.81116706}
# {'name1': 'Smilax lanceaefolia Roxb.', 'name2': 'Smilax ovalifolia Roxb.', 'similarity': 0.8477877}
# {'name1': 'Solanum dulcamara L.', 'name2': 'Solanum indicum L.', 'similarity': 0.8348012}
# {'name1': 'Solanum dulcamara L.', 'name2': 'Solanum melongena L.', 'similarity': 0.8355756}
# {'name1': 'Solanum dulcamara L.', 'name2': 'Solanum nigrum L.', 'similarity': 0.8074691}
# {'name1': 'Solanum dulcamara L.', 'name2': 'Solanum surattense Burm.f.', 'similarity': 0.8112776}
# {'name1': 'Solanum dulcamara L.', 'name2': 'Solanum trilobatum L.', 'similarity': 0.8194062}
# {'name1': 'Solanum erianthum D.Don', 'name2': 'Solanum indicum L.', 'similarity': 0.8192049}
# {'name1': 'Solanum erianthum D.Don', 'name2': 'Solanum nigrum L.', 'similarity': 0.82386684}
# {'name1': 'Solanum ferox L.', 'name2': 'Solanum nigrum L.', 'similarity': 0.81666094}
# {'name1': 'Solanum indicum L.', 'name2': 'Solanum melongena L.', 'similarity': 0.83299994}
# {'name1': 'Solanum indicum L.', 'name2': 'Solanum nigrum L.', 'similarity': 0.8641186}
# {'name1': 'Solanum indicum L.', 'name2': 'Solanum surattense Burm.f.', 'similarity': 0.8346151}
# {'name1': 'Solanum melongena L.', 'name2': 'Solanum nigrum L.', 'similarity': 0.85639757}
# {'name1': 'Solanum nigrum L.', 'name2': 'Solanum trilobatum L.', 'similarity': 0.81844074}
# {'name1': 'Solanum nigrum L.', 'name2': 'Solanum tuberosum L.', 'similarity': 0.80581343}
# {'name1': 'Sphaeranthus africanus L.', 'name2': 'Sphaeranthus indicus L.', 'similarity': 0.83330345}
# {'name1': 'Tephrosia purpurea (L.) Pers.', 'name2': 'Tephrosia uniflora Pers.', 'similarity': 0.85073155}
# {'name1': 'Tephrosia purpurea (L.) Pers.', 'name2': 'Tephrosia villosa (L.) Pers.', 'similarity': 0.867242}
# {'name1': 'Tephrosia uniflora Pers.', 'name2': 'Tephrosia villosa (L.) Pers.', 'similarity': 0.82404125}
# {'name1': 'Teucrium polium L.', 'name2': 'Teucrium scordium L.', 'similarity': 0.8362777}
# {'name1': 'Thymus serpyllum L.', 'name2': 'Thymus vulgaris L.', 'similarity': 0.81073177}
# {'name1': 'Trichosanthes cordata Roxb.', 'name2': 'Trichosanthes dioica Roxb.', 'similarity': 0.81282043}
# {'name1': 'Trifolium pratense L.', 'name2': 'Trifolium repens L.', 'similarity': 0.88859105}
# {'name1': 'Vernonia cineria (L.) Less.', 'name2': 'Vernonia squarrosa (D.Don) Less.', 'similarity': 0.82564294}
# {'name1': 'Ziziphus jujuba Mill.', 'name2': 'Ziziphus oenoplia (L.) Mill.', 'similarity': 0.806175}
# {'name1': 'Ziziphus mauritiana Lam.', 'name2': 'Ziziphus rugosa Lam.', 'similarity': 0.8460088}
# {'name1': 'Putranjiva Roxburghii Wall', 'name2': 'Putranjiva Roxburghii Wall', 'similarity': 1.0}

# %%
# Iterate over the duplicates and print only those with similarity > 0.9
for dup in duplicates:
    if dup["similarity"] > 0.9:
        print(f"Duplicate pair: {dup['name1']} and {dup['name2']} (Similarity: {dup['similarity']:.3f})")
# Out:
# Duplicate pair: Alhagi pseudoalhagi (Bieb.) Desv. and Alhagi pseudoalhagi (Bieb.) Desv. (Similarity: 1.000)
# Duplicate pair: Cassia alata L. and Cassia alata L. (Similarity: 1.000)
# Duplicate pair: Cordia myxa Roxb. and Cordia myxa Roxb. (non L.) (Similarity: 0.934)
# Duplicate pair: Elaeagnus angustifolia L. and Elaeagnus latifolia L. (Similarity: 0.937)
# Duplicate pair: Euphorbia nivulea Buch.-Ham. and Euphorbia nivulea Buch.-Ham. (Similarity: 1.000)
# Duplicate pair: Garcinia cambogia (Gaertn.) Desr. and Garcinia morella (Gaertn.) Desr. (Similarity: 0.910)
# Duplicate pair: Heliotropium bacciferum Forsk. and Heliotropium ovalifolium Forsk. (Similarity: 0.905)
# Duplicate pair: Rumex acetosa L. and Rumex acetosella L. (Similarity: 0.902)
# Duplicate pair: Putranjiva Roxburghii Wall and Putranjiva Roxburghii Wall (Similarity: 1.000)
